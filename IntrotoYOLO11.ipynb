# %% [markdown]
# https://github.com/ultralytics/ultralytics

# %%
! pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
# ...

# %%
#------------------------Object detection------------------------------------------

# %%
from ultralytics import YOLO

# load a pretrained OLO11n model
model = YOLO("yolo11n.pt")

# Perform object detection on an image
results = model("fruits.jpeg")  # Predict on an image
results[0].show()  # Display results
# Out:
# image 1/1 C:\Data_Science\fruits.jpeg: 544x640 4 apples, 6 oranges, 194.3ms
# Speed: 16.7ms preprocess, 194.3ms inference, 12.6ms postprocess per image at shape (1, 3, 544, 640)

# %%
# Perform object detection on an image
results = model("fruits.jpeg")  # Predict on an image
results[0].show()  # Display results
# Out:
# image 1/1 C:\Data_Science\fruits.jpeg: 544x640 4 apples, 6 oranges, 118.4ms
# Speed: 10.1ms preprocess, 118.4ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)

# %%
#----------------------------------Pose------------------------------------------

# %%
from ultralytics import YOLO

# load a pretrained YOLO11n model
model = YOLO("yolo11n-pose.pt")

# Perform object detection on an image
results = model("fruits.jpeg")  # Predict on an image
results[0].show()  # Display results
# Out:
# ...
#
# image 1/1 C:\Data_Science\fruits.jpeg: 544x640 (no detections), 115.6ms
# Speed: 3.5ms preprocess, 115.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)

# %%
from ultralytics import YOLO

# load a pretrained OLO11n model
model = YOLO("yolo11n-pose.pt")

# Perform object detection on an image
results = model("running.jpeg")  # Predict on an image
results[0].show()  # Display results
# Out:
# image 1/1 C:\Data_Science\running.jpeg: 448x640 5 persons, 120.5ms
# Speed: 4.7ms preprocess, 120.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
#-----------------------------------Classification-----------------------------------

# %%
from ultralytics import YOLO

# load a pretrained OLO11n model
model = YOLO("yolo11n-cls.pt")

# Perform object detection on an image
results = model("fruits.jpeg")  # Predict on an image
results[0].show()  # Display results
# Out:
# ...
#
# image 1/1 C:\Data_Science\fruits.jpeg: 224x224 strawberry 0.68, hamper 0.18, pineapple 0.06, custard_apple 0.02, maraca 0.02, 24.3ms
# Speed: 14.6ms preprocess, 24.3ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# ...

# %%
from ultralytics import YOLO

# load a pretrained OLO11n model
model = YOLO("yolo11n-cls.pt")

# Perform object detection on an image
results = model("runner.jpeg")  # Predict on an image
results[0].show()  # Display results
# Out:
# image 1/1 C:\Data_Science\runner.jpeg: 224x224 ballplayer 0.19, parallel_bars 0.15, balance_beam 0.11, baseball 0.10, basketball 0.07, 26.6ms
# Speed: 3.7ms preprocess, 26.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
from ultralytics import YOLO

# load a pretrained OLO11n model
model = YOLO("yolo11n-cls.pt")

# Perform object detection on an image
results = model("butterfly.jpeg")  # Predict on an image
results[0].show()  # Display results
# Out:
# image 1/1 C:\Data_Science\butterfly.jpeg: 224x224 monarch 0.85, ringlet 0.11, sulphur_butterfly 0.02, lycaenid 0.01, bee 0.00, 48.1ms
# Speed: 16.1ms preprocess, 48.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
from ultralytics import YOLO

# load a pretrained OLO11n model
model = YOLO("yolo11n.pt")

# Perform object detection on an image
results = model("/content/child-father.mp4", save = True)  # Predict on an image
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/351) /content/child-father.mp4: 384x640 2 persons, 9.6ms
# video 1/1 (frame 2/351) /content/child-father.mp4: 384x640 2 persons, 10.4ms
# video 1/1 (frame 3/351) /content/child-father.mp4: 384x640 2 persons, 12.2ms
# video 1/1 (frame 4/351) /content/child-father.mp4: 384x640 2 persons, 13.1ms
# video 1/1 (frame 5/351) /content/child-father.mp4: 384x640 2 persons, 10.9ms
# ...
